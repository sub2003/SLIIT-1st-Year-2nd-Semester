# %%
if True:
    print("Subhanu")
elif True:
    print("Ravisankha")
else:
    print("Aththanayaka")
# Out:
# Subhanu

# %%
for i in "Subhanu":
    print(i)
# Out:
# S
# u
# b
# h
# a
# n
# u

# %%
a={1,2,3,4}
b={"e","f","c","d"}
a.union(b)


#print(a.union(b))
a.intersection(b)
# Out:
# set()

# %%
a={1,2,3,4}
b={"e","f","c","d"}
a.union(b)


#print(a.union(b))
a.intersection(b)# this is not printing because below statement
print(a.union(b))
a.intersection(b)
# Out:
# {1, 2, 3, 4, 'c', 'd', 'e', 'f'}
# set()

# %%
a.difference(b)
# Out:
# {1, 2, 3, 4}

# %%
t = (1, "Subhanu", 3.5, True)
print(t)
print(t[0])

t[0]=10  # immutable
print(t)
# Out:
# (1, 'Subhanu', 3.5, True)
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 5
#       2 print(t)
#       3 print(t[0])
# ----> 5 t[0]=10  # immutable
#       6 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
s="Subhanu"
print(s[3])

s[3]="l" # immutable
# Out:
# h
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 4
#       1 s="Subhanu"
#       2 print(s[3])
# ----> 4 s[3]="l" # immutable
#
# TypeError: 'str' object does not support item assignment

# %%
l=list(t)  # convert tuple into list
print(y[1])

s=set(t)
print(s)  # not printing True because. when we convert that tuple into set in python True==1 so both 1 and True represent same. so in a set ther cant be same value twice. so thats why True is redundant because there existing 1 
#   True and 1 have the same value and the same hash, so a set treats them as the same element.
"""
A set removes duplicates based on:

1.Hash value
2.Equality (==)

In Python:

True == 1        → True
hash(True) == hash(1)   → True

"""

print(s[2])  #   set elements cant access seperately like list
# Out:
# Subhanu
# {1, 3.5, 'Subhanu'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[104], line 20
#       6 #   True and 1 have the same value and the same hash, so a set treats them as the same element.
#       7 """
#       8 A set removes duplicates based on:
#       9
#    (...)     17
#      18 """
# ---> 20 print(s[2])  #   set elements cant access seperately like list
#
# TypeError: 'set' object is not subscriptable

# %%
convertSetToList=list(s)
print(convertSetToList)
print(convertSetToList[2])  # if we want to access an element or update an element in a set we should convert it into a list.
convertSetToList[2]=1000  
# convertSetToList[3]=1000  ## we cant do lie tis. the method is below one.
convertSetToList.append("")
convertSetToList[3]=1000
print(convertSetToList)

s=set(convertSetToList)  # The we can convert it in to a set again. because if we want set behaiors rather than a set behaviors.
# wen we converting list into a set same/equal values redundet  so one 1000 id removed from list 
print(s)
print(list(s))
# Out:
# [1, 3.5, 'Subhanu']
# Subhanu
# [1, 3.5, 1000, 1000]
# {1000, 1, 3.5}
# [1000, 1, 3.5]

# %%
setToTuple=tuple(s)  # convert set into tuple
print(setToTuple)
# Out:
# (1000, 1, 3.5)

# %%
setToDictionary=dict(s)
print(setToDictionary)  # we can't convert set in to dictionary because there should be (key part,value part) .
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 setToDictionary=dict(s)
#       2 print(setToDictionary)  # we can't convert set in to dictionary because there should be (key part,value part) .
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
t2 = (("a", 1), ("b", 2))
d=dict(t2)
print(d)  # we can convert this, because there are two values per item
# Out:
# {'a': 1, 'b': 2}

# %%
dictionaryToSet=set(d)
print(dictionaryToSet)  # its only show key values
# Out:
# {'a', 'b'}

# %%
tupleToSet=set(d)
print(tupleToSet) # its only show key value
# Out:
# {'a', 'b'}

# %%
#if we want to get exact dictionary type set.

dictionaryToSet=set(d)  #=dictionaryT0Set=set(d.keys())
print(dictionaryToSet)

dictionaryTypeSet=set(d.items())
print(dictionaryTypeSet)
# Out:
# {'a', 'b'}
# {('b', 2), ('a', 1)}

# %%
i = {'c':1}

if i not in d:
    print("Yes 100000000 not in dictionary named as d")



'''
{'c':1} is a dictionary, and dictionaries are not *****hashable*****, so they cannot be used as keys and cannot be checked with in like that.

*****  unhashable type: 'dict'
'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 3
#       1 i = {'c':1}
# ----> 3 if i not in d:
#       4     print("Yes 100000000 not in dictionary named as d")
#       8 '''
#       9 {'c':1} is a dictionary, and dictionaries are not *****hashable*****, so they cannot be used as keys and cannot be checked with in like that.
#      10 '''
#
# TypeError: unhashable type: 'dict'

# %%
i = 100000000

if i not in d:
    print("Yes 100000000 not in dictionary named as d")
# Out:
# Yes 100000000 not in dictionary named as d

# %%
i = 'a'  

if i not in d:
    print("Yes 100000000 not in dictionary named as d")

# %%
i = 'a'

if i not in d.keys():  # this is actually happening internally in above one
    print("Yes 100000000 not in dictionary named as d")

# %%
i = 1

if i not in d:  # even though there is 1 in ds' value part. it only consider key part 
    print("Yes 100000000 not in dictionary named as d")
# Out:
# Yes 100000000 not in dictionary named as d

# %%
i = 1

if i not in d.values(): #if we cant to check value part, we should do like this.
    print("Yes 100000000 not in dictionary named as d")

# %%
v = 1
k='b'
if (k,v) not in d.items(): #if we cant to check both parts, we should do like this.
    print("Yes 100000000 not in dictionary named as d")
# Out:
# Yes 100000000 not in dictionary named as d

# %%
v = 1
k='a'
if (k,v) not in d.items(): #if we cant to check both parts, we should do like this.
    print("Yes 100000000 not in dictionary named as d")

# %%
x = {'x':1, 'y':2, 'z':3} 
for i in x: 
    print(i, end=' ')  # eventhough they are charcters its not showing in inside quotations.


print()

x = {'x':1, 'y':2, 'z':3} 
for i, j in x.items(): # eventhough they are charcters its not showing in inside quotations.
    print(i, j, end=' ')
# Out:
# x y z
# x 1 y 2 z 3

# %% [markdown]
# Lab Sheet 02
# Part 02
# Question 05

# %%
# I.

F = { "React" , "Angular" }
B = { "Node.js" , "Django" }

from itertools import product

pairs=set(product(F,B))
print(pairs)
print(list(pairs))
# Out:
# {('React', 'Django'), ('Angular', 'Node.js'), ('Angular', 'Django'), ('React', 'Node.js')}
# [('React', 'Django'), ('Angular', 'Node.js'), ('Angular', 'Django'), ('React', 'Node.js')]

# %%
# II.

from itertools import combinations

#D = {"Docker", "Kubernetes", "AWS"}

uCombinations=F.union(B)
#C={} # we can't use this. Because this creates dictionary. But "extend" works only with lists.
C=[]
for i in range(len(uCombinations)+1):
    C.extend(combinations(uCombinations,i))

print(C)
print("\n\n\n")
print(set(C))
# Out:
# [(), ('React',), ('Angular',), ('Django',), ('Node.js',), ('React', 'Angular'), ('React', 'Django'), ('React', 'Node.js'), ('Angular', 'Django'), ('Angular', 'Node.js'), ('Django', 'Node.js'), ('React', 'Angular', 'Django'), ('React', 'Angular', 'Node.js'), ('React', 'Django', 'Node.js'), ('Angular', 'Django', 'Node.js'), ('React', 'Angular', 'Django', 'Node.js')]
#
#
#
#
# {('React', 'Angular', 'Django', 'Node.js'), ('Angular',), ('React', 'Node.js'), ('Node.js',), ('React', 'Angular'), ('Django',), ('Angular', 'Node.js'), ('React', 'Django', 'Node.js'), ('Angular', 'Django'), ('React', 'Django'), ('Django', 'Node.js'), ('React', 'Angular', 'Node.js'), ('React', 'Angular', 'Django'), ('React',), (), ('Angular', 'Django', 'Node.js')}

# %%
D = {"Docker", "Kubernetes", "AWS"}

D_combinations=[]
for i in range(len(D)+1):
    D_combinations.extend(combinations(D,i))

print(D_combinations)

x=None

print("\n\n",x,"\n")

print(set(D_combinations))
# Out:
# [(), ('Kubernetes',), ('AWS',), ('Docker',), ('Kubernetes', 'AWS'), ('Kubernetes', 'Docker'), ('AWS', 'Docker'), ('Kubernetes', 'AWS', 'Docker')]
#
#
#  None
#
# {('Docker',), ('AWS', 'Docker'), ('Kubernetes', 'AWS'), ('AWS',), ('Kubernetes',), ('Kubernetes', 'Docker'), ('Kubernetes', 'AWS', 'Docker'), ()}

# %% [markdown]
# Lab Sheet 02 Part 01 Question 05

# %%
U=set(range(1,41))
C=set(range(1,16))
X=only_python=set(range(16,26))
Y=only_java=set(range(26,33))

A=X.union(C)
B=Y.union(C)

P=onlyPythomCoumt=len(A.difference(B))   # Or len(A - B) 
J=onlyJavaCount=len(B.difference(A))     # Or len(A - B)
PJ=at_least_one=len(A.union(B))          # Or len(A.union(B))
none=len(U.difference(A.union(B)))       # Or len(all_machines - A.union(B))

# I.
print(P)
# II.
print(J)
# III.
print(PJ)
# IV.
print(none)
# Out:
# 10
# 7
# 32
# 8

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
print(A.symmetric_difference(B))  
'''Or''' 
print(A.union(B)-A.intersection(B))
'''Or'''
print(A ^ B)
# Out:
# {1, 2, 5, 6}
# {1, 2, 5, 6}
# {1, 2, 5, 6}

# %%
car = {"brand":"Ford","year":2004}
#car.pop("year")
print(car.pop("year"))
print(car)
# Out:
# 2004
# {'brand': 'Ford'}

# %%
a = [1,4,"3"]
a.append(7)
a.insert(0,3) # insert 3 at index 0
print(a)
# Out:
# [3, 1, 4, '3', 7]

# %%
print(a.index("3")) # return index of corresponding value
# Out:
# 3

# %% [markdown]
# Extend key word

# %%
a = [1, 2] 
b = [3, 4] 
a.extend(b) 
print(a)
# Out:
# [1, 2, 3, 4]

# %%
D = {"Docker", "Kubernetes", "AWS"}

D_combinations=[]
for i in range(len(D)+1):
    D_combinations.extend(combinations(D,i))

print(D_combinations)

x=None

print("\n\n",x,"\n")

print(set(D_combinations))
# Out:
# [(), ('Kubernetes',), ('AWS',), ('Docker',), ('Kubernetes', 'AWS'), ('Kubernetes', 'Docker'), ('AWS', 'Docker'), ('Kubernetes', 'AWS', 'Docker')]
#
#
#  None
#
# {('Docker',), ('AWS', 'Docker'), ('Kubernetes', 'AWS'), ('AWS',), ('Kubernetes',), ('Kubernetes', 'Docker'), ('Kubernetes', 'AWS', 'Docker'), ()}

# %%
list2 = [2,4,5,6]
list3 = [2,6,7,8]

# %%
list2.extend(list3)
print(list2)
print(set(list2))
# Out:
# [2, 4, 5, 6, 2, 6, 7, 8]
# {2, 4, 5, 6, 7, 8}

# %%
list1 = [1,2,3,4]
list2 = [2,4,5,6]
list3 = [2,6,7,8]
result = list() # Or []
result.extend(i for i in list1 if i not in (list2+list3) and i not in result)
result.extend(i for i in list2 if i not in (list1+list3) and i not in result)
result.extend(i for i in list3 if i not in (list1+list2) and i not in result)

# %%
print(result)
# Out:
# [1, 3, 5, 7, 8]

# %%
print([i*2 for i in [1,2,3]])
print([i.upper() for i in ["a","b","c"]])
# Out:
# [2, 4, 6]
# ['A', 'B', 'C']

# %%
list1 = [1, 3]
list2 = list1   #Same list (reference)  *****************************************************
list1[0] = 4
print(list2)
# Out:
# [4, 3]

# %%
list1 = [1, 3]
list2 = list1.copy() #New list (copy)   *****************************************************

list1[0] = 4
print(list2)
# Out:
# [1, 3]

# %%
x = ('abcd', 786, 2.23, 'john', 70.2)
for i in x[1:3]:  #slice tuple(we can use this for lists dictionaries as well)  Loop through values
# same as for i in range(1,3)     
    print(i)
# Out:
# 786
# 2.23

# %%
values = [1,2,3,4] 
numbers = set(values) 
def checknums(num): 
    if num in numbers: 
        return True 
    else: 
        return False 
i=filter(checknums, values)
print(i)

# %%
marks = [45, 23, 67, 12, 89, 34, 55]
def is_pass(mark):
    return mark >= 50
result = filter(is_pass, marks)
'''

Internally Python does this:

is_pass(45) → False → skip
is_pass(23) → False → skip
is_pass(67) → True  → keep
is_pass(12) → False → skip
is_pass(89) → True  → keep
is_pass(34) → False → skip
is_pass(55) → True  → keep 
'''

print(marks)
# Out:
# [45, 23, 67, 12, 89, 34, 55]

# %%
from itertools import combinations

# Example sets (you must define these)
F = {"Docker", "Kubernetes"}
B = {"AWS"}

uCombinations = F.union(B)

C = []
for i in range(len(uCombinations) + 1):
    C.extend(combinations(uCombinations, i))

print(C)
print("\n\n\n")
print(set(C))
# Out:
# [(), ('Kubernetes',), ('AWS',), ('Docker',), ('Kubernetes', 'AWS'), ('Kubernetes', 'Docker'), ('AWS', 'Docker'), ('Kubernetes', 'AWS', 'Docker')]
#
#
#
#
# {('Docker',), ('AWS', 'Docker'), ('Kubernetes', 'AWS'), ('AWS',), ('Kubernetes',), ('Kubernetes', 'Docker'), ('Kubernetes', 'AWS', 'Docker'), ()}

# %%
S = {"A", "B", "C"} 
print(list(combinations(S,2)))
print(len(list(combinations(S,2))))
# Out:
# [('C', 'B'), ('C', 'A'), ('B', 'A')]
# 3

# %%
S = {"Python", "Java","C#"} 
print(list(combinations(S,1))) 
print(list(combinations(S,2)))
# Out:
# [('C#',), ('Java',), ('Python',)]
# [('C#', 'Java'), ('C#', 'Python'), ('Java', 'Python')]

# %%
temp = {'GFG':1, 'Facebook':2, 'Google':3} 
for (key, values) in temp.items(): 
    print(key, values, end=" ")
# Out:
# GFG 1 Facebook 2 Google 3

# %%
dictionary = {} 
dictionary[1] = 1 
dictionary['1'] = 2 
dictionary[1] += 1 
print(dictionary)
sum = 0 
for k in dictionary:
    print(k,end=" ")
    sum += dictionary[k] 
    print(sum)
print(sum)



print("\n\n",None,"\n")


for k in dictionary:
    if k==1:
        print(k)
    else:
        print(k+k)  # even though it's printing without quotations. The output is still the string type
# Out:
# {1: 2, '1': 2}
# 1 2
# 1 4
# 4
#
#
#  None
#
# 1
# 11
