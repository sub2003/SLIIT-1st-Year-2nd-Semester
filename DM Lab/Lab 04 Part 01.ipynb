# %% [markdown]
# Part 01

# %% [markdown]
# 1.

# %%
# I.

#An=n*n+3*n

n=10
sequence=[]
for i in range(n):
    sequence.append(i*i+3*i)

print(sequence)


# II.
total=0
for i in sequence:
    total+=i
print(total)
# Out:
# [0, 4, 10, 18, 28, 40, 54, 70, 88, 108]
# 420

# %% [markdown]
# 2.

# %%
# I.

#Tn=a*(r**(n-1))

a=300
r=2
n=10
gSequence=[]
for i in range(n):
    gSequence.append(a*(r**i))
print(gSequence)

# II.

toatl=0
for i in gSequence:
    total+=i
print(total)
# Out:
# [300, 600, 1200, 2400, 4800, 9600, 19200, 38400, 76800, 153600]
# 307320

# %% [markdown]
# 3.

# %%
# I.
a=5
n=15
d=4

sequence=[]
for i in range(1,n+1):
    sequence.append(a+(i-1)*d)
print(sequence)

# II.
total=0
for i in sequence:
    total+=i
print(total)

# III.

total=0
total = (n/2)*(2*a+(n-1)*d)
print(total)
# Out:
# [5, 9, 13, 17, 21, 25, 29, 33, 37, 41, 45, 49, 53, 57, 61]
# 495
# 495.0

# %% [markdown]
# 4.

# %%
total = 0
for j in range(5):
    total += (-2)**j
print(total)

total = sum((-2)**j for j in range(5))
print(total)
# Out:
# 11
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 6
#       3     total += (-2)**j
#       4 print(total)
# ----> 6 total = sum((-2)**j for j in range(5))
#       7 print(total)
#
# TypeError: 'int' object is not callable

# %%
population = 100
years = 10

total_increase = 0

for year in range(1, years+1):
    new_population = population + 0.15 * population - 5
    increase = new_population - population
    
    total_increase += increase
    population = new_population

print("Total population increase:", round(total_increase,2))
# Out:
# Total population increase: 203.04
