# %%
#while(True):
    
    while(True):
        num1=int(input("Enter 1st number : "))
        num2=int(input("Enter 2nd number : "))
        
        if (isinstance(num1, (int, float)) and isinstance(num2,(int,float))):
            
            while(True):
            
                operation=(input("Enter the operation to perform (+,-,x,/) : "))
                
                if(operation =='+' or operation=='-' 
                   or operation =='x' or operation=='/'):
                    break
                else:
                    continue
        else:
            continue
            
        value=0.0
        
        if(operation=='+'):
            value=num1+num2
        elif(operation=='-'):
            value=num1-num2
        elif(operation=='x'):
            value=num1*num2
        else:
            value=num1/num2

        print()
        print("The value is : ",value )
        print("\n\n")
# Out:
#   Cell In[1], line 3
#     while(True):
#     ^
# IndentationError: unexpected indent

# %%
a=[]
for(i in range(5)):
    a[i]=float(input("Enter subject ", (i+1), " marks : "))
    total=total+a[i]

print("Total Marks = ",total)

# %%
a=[]
for(i in range(5)):
    a[i]=float(input("Enter subject ", (i+1), " marks : "))
    total=total+a[i]

print("Total Marks = ",total)
