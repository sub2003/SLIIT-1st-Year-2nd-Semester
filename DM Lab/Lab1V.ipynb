# %% [markdown]
# 4

# %%
a=[0,0,0,0,0]
total=0
for i in range(5):
    a[i]=float(input(f"Enter subject {i+1} marks : "))
    total=total+a[i]

print("Total Marks = ",total)
# Out:
# Enter subject 1 marks :  100
# Enter subject 2 marks :  99
# Enter subject 3 marks :  98
# Enter subject 4 marks :  97
# Enter subject 5 marks :  96
# Total Marks =  490.0

# %%
while(True):
    password=input("Enter the password : ")
    
    if(password=="python123"):
        print("Access granted")
        return
    else:
        continue
# Out:
# Enter the password :  python123
# Access granted
