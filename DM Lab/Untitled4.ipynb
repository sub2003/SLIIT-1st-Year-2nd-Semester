# %% [markdown]
# 5

# %%
price=[]
total=0.0
i=0
while(True):
    price.append(float(input("Enter price of item : ")))
    
    if(price[i]>0) :
        total=total+price[i]
    elif((price[i]<=0) and (total>1000)):
        print("Checkout complete")
        break
    i=i+1
print(" Total amount to be paid : ",total)
# Out:
# Enter price of item :  1234
# Enter price of item :  35546
# Enter price of item :  7664
# Enter price of item :  -9
# Checkout complete
#  Total amount to be paid :  44444.0
