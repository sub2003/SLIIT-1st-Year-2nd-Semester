# %%
import sys

try:
    while True:
        password = input("Enter the password: ")
        if password == "python123":
            print("Access granted")
            sys.exit()
        else:
            continue
except SystemExit:
    print("Program terminated successfully")
# Out:
# Enter the password:  pythoan
# Enter the password:  python123
# Access granted
# Program terminated successfully

# %% [markdown]
# ***PART 02***

# %% [markdown]
# 1

# %%
# I
x=15
y=10
# (a)
print(x>y)
# (b)
print(x==y)
# (c)
print(x!=y)
# Out:
# True
# False
# True

# %%
# II
print(10<=20)
# Out:
# True

# %%
# III
print(5>3 and 10>5)
# Out:
# True

# %% [markdown]
# 2

# %%
weight=float(input("Enter the weight(kg) : "))
height=float(input("Enter the height(m) : "))

BMI=weight/(height*height)

print(f"BMI : {BMI:.2f} (kg/m²)")

if(BMI<18):
    print("Underweight")
elif(BMI<=25):
    print("Normal")
else:
    print("Overweight")
# Out:
# Enter the weight(kg) :  54
# Enter the height(m) :  1.65
# BMI : 19.83 (kg/m²)
# Normal

# %% [markdown]
# 3

# %% [markdown]
# name=input("Student's name : ")
# subject=[0,0,0]
# total=0.0
# for i in range(3):
#     subject[i]=float(input(f"Enter subject {i+1} marks : "))
#     total=total+subject[i]
# percentage=total/len(subject)
#
# grade=""
# if(percentage>=75):
#     grade='A'
# elif(percentage>=60):
#     grade='B'
# elif(percentage>=45):
#     grade='C'
# elif(percentage>=30):
#     grade='D'
# else:
#     grade='F'
#
# print("----Mark Sheet----")
# print("Student name : ",name)
# for i in range(3):
#     print(f"subject {i+1} marks = ",subject[i])
# print("total marks = ",total)
# print("Percentage = ",percentage)
# print("Grade = ",grade)

# %% [markdown]
# 4

# %%
sum=0
while(True):

  
        
    naturalNumber=int(input("Enter number : "))
    if(naturalNumber>0):
        sum=sum+naturalNumber
    if(naturalNumber<0):
        print("Total = ",sum)
        break
# Out:
# Enter number :  12
# Enter number :  12
# Enter number :  12
# Enter number :  12
# Enter number :  -9
# Total =  48

# %% [markdown]
# 5

# %%
price=[]
while(False):
    price.append(float(input("Enter price of item")))
# Out:
# Enter price of item 12
# Enter price of item 12
