# %% [markdown]
# 3

# %%
while(True):
    
    while(True):
        num1=int(input("Enter 1st number : "))
        num2=int(input("Enter 2nd number : "))
        
        if (isinstance(num1, (int, float)) and isinstance(num2,(int,float))):
            
            while(True):
            
                operation=(input("Enter the operation to perform (+,-,x,/) : "))
                
                if(operation =='+' or operation=='-' 
                   or operation =='x' or operation=='/'):
                    break
                else:
                    continue
        else:
            continue
            
        value=0.0
        
        if(operation=='+'):
            value=num1+num2
        elif(operation=='-'):
            value=num1-num2
        elif(operation=='x'):
            value=num1*num2
        else:
            value=num1/num2

        print()
        print("The value is : ",value )
        print("\n\n")
# Out:
# Enter 1st number :  23
# Enter 2nd number :  12
# Enter the operation to perform (+,-,x,/) :  +
# The value is :  35
# Enter 1st number :  23
# Enter 2nd number :  34
# Enter the operation to perform (+,-,x,/) :  -
# The value is :  -11
# Enter 1st number :  67
# Enter 2nd number :  45
# Enter the operation to perform (+,-,x,/) :  x
# The value is :  3015
# Enter 1st number :  45
# Enter 2nd number :  56
# Enter the operation to perform (+,-,x,/) :  /
# The value is :  0.8035714285714286
